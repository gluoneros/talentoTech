# %% [markdown]
# # Seaborn

# %%
import pandas as pd

data = pd.read_csv('FuelEfficiency.csv')

data
# Out:
#                 Mfr Name                 Carline  Eng Displ  Cylinders  \
# 0           aston martin              Vantage V8        4.0          8
# 1    Volkswagen Group of                  Chiron        8.0         16
# 2         General Motors                CORVETTE        6.2          8
# 3         General Motors                CORVETTE        6.2          8
# 4         General Motors                CORVETTE        6.2          8
# ..                   ...                     ...        ...        ...
# 713               Toyota             4RUNNER 4WD        4.0          6
# 714               Toyota  LAND CRUISER WAGON 4WD        5.7          8
# 715               Toyota             SEQUOIA 4WD        5.7          8
# 716                Volvo                XC90 AWD        2.0          4
# 717                Volvo                XC90 AWD        2.0          4
#
#     Transmission  CityMPG  HwyMPG  CombMPG  # Gears
# 0       Auto(S8)       18      25       21        8
# ...

# %%
cambios = data['# Gears'].value_counts()

cambios.plot(kind='bar')
# Out:
# <Axes: xlabel='# Gears'>

# %%
import seaborn as sns

sns.set()

# %%
cambios.plot(kind='bar')
# Out:
# <Axes: xlabel='# Gears'>

# %%
sns.distplot(data['CombMPG'])
# Out:
# <ipython-input-10-234ea4d1e034>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['CombMPG'])
# <Axes: xlabel='CombMPG', ylabel='Density'>

# %%
consumo_comb = data[['Cylinders','CityMPG','HwyMPG','CombMPG']]
consumo_comb
# Out:
#      Cylinders  CityMPG  HwyMPG  CombMPG
# 0            8       18      25       21
# 1           16        9      14       11
# 2            8       12      20       15
# 3            8       15      25       18
# 4            8       14      23       17
# ..         ...      ...     ...      ...
# 713          6       17      20       18
# 714          8       13      18       15
# 715          8       13      17       14
# 716          4       19      26       22
# 717          4       20      27       23
#
# [718 rows x 4 columns]

# %%
sns.pairplot(consumo_comb)

# %%
sns.scatterplot(x='Eng Displ',y='CombMPG',data=data)
# Out:
# <Axes: xlabel='Eng Displ', ylabel='CombMPG'>

# %%
sns.jointplot(x='Eng Displ',y='CombMPG',data=data)

# %%
sns.lmplot(x='Eng Displ',y='CombMPG',data=data)

# %%
sns.set(rc={'figure.figsize':(16,5)})

eje_x = sns.boxplot(x='Mfr Name', y='CombMPG', data=data)

eje_x.set_xticklabels(eje_x.get_xticklabels(), rotation=90)
# Out:
# <ipython-input-20-debc4edf805e>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   eje_x.set_xticklabels(eje_x.get_xticklabels(), rotation=90)
# [Text(0, 0, 'aston martin'),
#  Text(1, 0, 'Volkswagen Group of'),
#  Text(2, 0, 'General Motors'),
#  Text(3, 0, 'Ferrari'),
#  Text(4, 0, 'FCA US LLC'),
#  Text(5, 0, 'Jaguar Land Rover L'),
#  Text(6, 0, 'MAZDA'),
#  Text(7, 0, 'Nissan'),
#  Text(8, 0, 'Porsche'),
#  Text(9, 0, 'BMW'),
#  Text(10, 0, 'Subaru'),
#  Text(11, 0, 'Toyota'),
#  Text(12, 0, 'Ford Motor Company'),
#  Text(13, 0, 'Mercedes-Benz'),
#  Text(14, 0, 'Honda'),
#  Text(15, 0, 'Hyundai'),
#  Text(16, 0, 'Rolls-Royce'),
#  Text(17, 0, 'Volvo'),
#  Text(18, 0, 'Kia'),
#  Text(19, 0, 'Maserati'),
#  Text(20, 0, 'Mitsubishi Motors Co')]

# %%
eje_x = sns.swarmplot(x='Mfr Name', y='CombMPG', data=data)

eje_x.set_xticklabels(eje_x.get_xticklabels(), rotation=90)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 31.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 30.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 29.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# # Smart Home Energy Usage

# %%
import pandas as pd

data = pd.read_csv('smart_home_energy_usage_dataset.csv')

data
# Out:
#                   timestamp  home_id  energy_consumption_kWh  \
# 0       2023-01-01 00:00:00       44                    2.87
# 1       2023-01-01 01:00:00       81                    0.56
# 2       2023-01-01 02:00:00       94                    4.49
# 3       2023-01-01 03:00:00       20                    2.13
# 4       2023-01-01 04:00:00        3                    2.74
# ...                     ...      ...                     ...
# 999995  2137-01-29 11:00:00        2                    1.35
# 999996  2137-01-29 12:00:00       37                    2.09
# 999997  2137-01-29 13:00:00       64                    0.43
# 999998  2137-01-29 14:00:00       53                    0.16
# 999999  2137-01-29 15:00:00       60                    2.95
#
#         temperature_setting_C occupancy_status     appliance  \
# 0                        22.1         Occupied  Refrigerator
# 1                        15.4         Occupied          HVAC
# ...

# %%
data['appliance'].value_counts()
# Out:
# appliance
# Lighting           167310
# Refrigerator       166804
# Electronics        166638
# Dishwasher         166629
# Washing Machine    166378
# HVAC               166241
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data.describe()
# Out:
#               home_id  energy_consumption_kWh  temperature_setting_C  \
# count  1000000.000000          1000000.000000         1000000.000000
# mean        50.019812                2.548839              19.999284
# std         28.605155                1.415527               2.887678
# min          1.000000                0.100000              15.000000
# 25%         25.000000                1.320000              17.500000
# 50%         50.000000                2.550000              20.000000
# 75%         75.000000                3.780000              22.500000
# max         99.000000                5.000000              25.000000
#
#        usage_duration_minutes         holiday
# count          1000000.000000  1000000.000000
# mean                59.505089        0.099588
# std                 34.651890        0.299450
# min                  0.000000        0.000000
# 25%                 30.000000        0.000000
# 50%                 59.000000        0.000000
# ...

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['energy_consumption_kWh'], bins=10, color='blue', edgecolor='black')
plt.title('Distribución del Consumo de Energía (kWh)')
plt.xlabel('Consumo de Energía (kWh)')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
appliance_energy = data.groupby('appliance')['energy_consumption_kWh'].mean()

plt.figure(figsize=(10, 6))
appliance_energy.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Consumo de Energía por Tipo de Electrodoméstico')
plt.xlabel('Tipo de Electrodoméstico')
plt.ylabel('Consumo de Energía (kWh)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Titanic

# %%
df_titanic = pd.read_csv('Titanic.csv')

df_titanic.describe()
# Out:
#        PassengerId       Pclass          Age        SibSp        Parch  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean    500.500000     1.964000    38.458000     2.032000     2.005000
# std     288.819436     0.820596    23.103723     1.424431     1.410306
# min       1.000000     1.000000     1.000000     0.000000     0.000000
# 25%     250.750000     1.000000    19.000000     1.000000     1.000000
# 50%     500.500000     2.000000    36.500000     2.000000     2.000000
# 75%     750.250000     3.000000    59.000000     3.000000     3.000000
# max    1000.000000     3.000000    79.000000     4.000000     4.000000
#
#               Fare     Survived
# count  1000.000000  1000.000000
# mean    247.968650     0.492000
# std     139.301211     0.500186
# min      10.020000     0.000000
# 25%     126.295000     0.000000
# 50%     246.500000     0.000000
# 75%     365.662500     1.000000
# max     499.780000     1.000000

# %%
df_titanic.head()
# Out:
#    PassengerId  Pclass             Name     Sex  Age  SibSp  Parch  \
# 0            1       3     Allison Hill    male   17      4      2
# 1            2       1      Noah Rhodes    male   60      2      2
# 2            3       3  Angie Henderson    male   64      0      0
# 3            4       3    Daniel Wagner    male   35      4      0
# 4            5       1  Cristian Santos  female   70      0      3
#
#                                  Ticket    Fare Embarked  Survived
# 0  43d75413-a939-4bd1-a516-b0d47d3572cc  144.08        Q         1
# 1  6334fa2a-8b4b-47e7-a451-5ae01754bf08  249.04        S         0
# 2  61a66444-e2af-4629-9efb-336e2f546033   50.31        Q         1
# 3  0b6c03c8-721e-4419-afc3-e6495e911b91  235.20        C         1
# 4  436e3c49-770e-49db-b092-d40143675d58  160.17        C         1

# %%
correlacion = df_titanic[['Survived','Pclass','Age','SibSp','Parch','Fare']].corr()

sns.heatmap(correlacion, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.set(rc={'figure.figsize':(16,5)})

eje_x = sns.boxplot(x='Sex', y='Age', data=df_titanic)

eje_x.set_xticklabels(eje_x.get_xticklabels(), rotation=90)
# Out:
# <ipython-input-52-c7ae7ea15f6e>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   eje_x.set_xticklabels(eje_x.get_xticklabels(), rotation=90)
# [Text(0, 0, 'male'), Text(1, 0, 'female')]
